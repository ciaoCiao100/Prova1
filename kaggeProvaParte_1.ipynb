# %% [markdown]
# <a href="https://colab.research.google.com/github/ciaoCiao100/Prova1/blob/master/kaggeProvaParte_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import functools
import numpy as np
import tensorflow as tf
from sklearn import tree
import matplotlib as plt
import nltk

import sklearn.metrics as metrics
import sklearn
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from tensorflow import feature_column
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
 

# operazione che fa in modo che i numeri siano più leggibili
np.set_printoptions(precision=3, suppress=True)

customer_file_path = "/content/drive/My Drive/WA_Fn-UseC_-Telco-Customer-Churn.train.csv"
df = pd.read_csv(customer_file_path)
df.head()
# Out:
#   Churn  customerID  ... MonthlyCharges  TotalCharges
# 0    No  4223-BKEOR  ...          64.85        1336.8
# 1    No  6035-RIIOM  ...          97.20       5129.45
# 2   Yes  3797-VTIDR  ...          23.45         23.45
# 3   Yes  2568-BRGYX  ...          70.20        237.95
# 4    No  2775-SEFEE  ...          61.90
#
# [5 rows x 21 columns]

# %% [markdown]
# divido il dataset e creo due file di train e test

# %%
train, test = train_test_split(df, test_size=0.1)
train= df.to_csv('train.csv', index = True)
test = df.to_csv('test.csv',index = True)
